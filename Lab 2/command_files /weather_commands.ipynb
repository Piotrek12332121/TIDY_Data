# %% [markdown]
# Plik weather.txt został wgrany do excela i przy jego pomocy wygenerowałem plik weather.csv. Wszystkie wystąpienia liczby -9999 ( nierealnej jako wskazania temperatury) zostały zastąpione jako None. Następnie przy pomocy .iloc wybieram tylko dane z zadanego przedziału ( pierwsze 5 miesięcy 2010 roku)

# %%
import pandas as pd
import numpy as np
data_frame=pd.read_csv("weather.csv",sep=';', header=None)
data_frame=data_frame.replace(-9999,None)

first_5m_2010=data_frame.iloc[1668:1683,:]

first_5m_2010
# Out:
#                          0     1     2     3     4     5     6     7     8   \
# 1668  MX000017004201001TMAX  None  None  None  None  None  None  None  None
# 1669  MX000017004201001TMIN  None  None  None  None  None  None  None  None
# 1670  MX000017004201001PRCP  None  None  None  None     0  None     0  None
# 1671  MX000017004201002TMAX  None   273   241  None  None  None  None  None
# 1672  MX000017004201002TMIN  None   144   144  None  None  None  None  None
# 1673  MX000017004201002PRCP  None     0     0  None  None     0     0  None
# 1674  MX000017004201003TMAX  None  None  None  None   321  None  None  None
# 1675  MX000017004201003TMIN  None  None  None  None   142  None  None  None
# 1676  MX000017004201003PRCP  None     0  None     0     0     0  None  None
# 1677  MX000017004201004TMAX  None  None  None  None  None  None  None  None
# 1678  MX000017004201004TMIN  None  None  None  None  None  None  None  None
# ...
